# %% [markdown]
# ## First Delivery: 1st July
# A static visualization of the Covid cases always 3 countries of your choice are in each figure
# - Delivery 1 - Figure 1 The relative cases overtime of Covid infectors (absolut Covid cases/population size)
# - Delivery 2 - Figure 2 The vaccination rate (percentage of the population) over time

# %%
# importing neccesary libraries for the visualization
import pandas as pd
import plotly.express as px
# %matplotlib inline

# %%
# importing the data of countries
# India, Germany, France
countries_df = pd.read_csv("E:/uni/Data_Science_E/Data_Science_Enterprise/data/countries_df.csv")
countries_df.head(5)
# Out:
#   iso_code continent location        date  total_cases  new_cases  \
# 0      FRA    Europe   France  2020-01-24          2.0        2.0
# 1      FRA    Europe   France  2020-01-25          3.0        1.0
# 2      FRA    Europe   France  2020-01-26          3.0        0.0
# 3      FRA    Europe   France  2020-01-27          3.0        0.0
# 4      FRA    Europe   France  2020-01-28          4.0        1.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %% [markdown]
# ## Delivery 1
# The relative cases overtime of Covid infectors (absolut Covid cases/population size)

# %%
fig = px.line(countries_df, x='date',y='cases2population',color='location',title = "COVID cases")
fig.show()
# Out:
# <div>                            <div id="8bc50a1d-5141-480d-a065-156b5ac4c9be" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8bc50a1d-5141-480d-a065-156b5ac4c9be")) {                    Plotly.newPlot(                        "8bc50a1d-5141-480d-a065-156b5ac4c9be",                        [{"hovertemplate":"location=France<br>date=%{x}<br>cases2population=%{y}<extra></extra>","legendgroup":"France","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"France","showlegend":true,"x":["2020-01-24","2020-01-25","2020-01-26","2020-01-27","2020-01-28","2020-01-29","2020-01-30","2020-01-31","2020-02-01","2020-02-02","2020-02-03","2020-02-04","2020-02-05","2020-02-06","2020-02-07","2020-02-08","2020-02-09","2020-02-1
# ...

# %% [markdown]
# ## Delivery 2
# The vaccination rate (percentage of the population) over time

# %% [markdown]
# for vaccination percentage, we will have to compute
#
# vaccination rate = (total_vaccinations/population)*100

# %%
countries_df['vaccination_rate'] = countries_df.apply(lambda x: (x['total_cases']/x['population'])*100, axis=1)

# %%
fig = px.line(countries_df, x='date',y='vaccination_rate',color='location',title = "Vaccination Rate")
fig.show()
# Out:
# <div>                            <div id="5bec1aba-c3c6-49c6-8fa9-9869b6143ea2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5bec1aba-c3c6-49c6-8fa9-9869b6143ea2")) {                    Plotly.newPlot(                        "5bec1aba-c3c6-49c6-8fa9-9869b6143ea2",                        [{"hovertemplate":"location=France<br>date=%{x}<br>vaccination_rate=%{y}<extra></extra>","legendgroup":"France","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"France","showlegend":true,"x":["2020-01-24","2020-01-25","2020-01-26","2020-01-27","2020-01-28","2020-01-29","2020-01-30","2020-01-31","2020-02-01","2020-02-02","2020-02-03","2020-02-04","2020-02-05","2020-02-06","2020-02-07","2020-02-08","2020-02-09","2020-02-1
# ...
